# %%
# %matplotlib inline
import joblib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Conv2D, MaxPooling2D, Flatten, Dropout
from pandas.plotting import scatter_matrix 
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import cohen_kappa_score
from tensorflow.keras.optimizers import Adam
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from keras.preprocessing import image

# %% [markdown]
# Построим датасет из исходных изобраений применив к ним различные трансформации

# %%
image_size = (128, 128)
batch_size = 32
base_dir = 'flowers'


train_datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2,  
                                   zoom_range=0.2, horizontal_flip=True, 
                                   validation_split=0.2) 
  
test_datagen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2,  
                                   zoom_range=0.2, horizontal_flip=True, 
                                   validation_split=0.2)  
  
train_data = train_datagen.flow_from_directory(base_dir, 
                                               target_size=image_size, 
                                               subset='training', 
                                               batch_size=batch_size, 
                                               class_mode='categorical') 
val_data = test_datagen.flow_from_directory(base_dir,
                                            target_size=image_size,
                                            subset='validation',
                                            batch_size=batch_size, 
                                            class_mode='categorical')
# Out:
# Found 3457 images belonging to 5 classes.
# Found 860 images belonging to 5 classes.

# %% [markdown]
# Создадим модель сверточной нейронной сети и обучим её

# %%
model = Sequential() 
model.add(Input(shape=(128, 128, 3)))
model.add(Conv2D(filters=64, kernel_size=(5, 5), padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2))) 
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2))) 
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2))) 
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')) 
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2))) 
model.add(Flatten()) 
model.add(Dropout(0.25))
model.add(Dense(512, activation='relu'))
model.add(Dense(5, activation="softmax"))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, epochs=20, batch_size=32, validation_data=val_data)
# Out:
# Epoch 1/20
# C:\Users\mkiri\anaconda3\envs\tf_keras\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 76s 659ms/step - accuracy: 0.3348 - loss: 1.4424 - val_accuracy: 0.5640 - val_loss: 1.0997
# Epoch 2/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 75s 677ms/step - accuracy: 0.5620 - loss: 1.0998 - val_accuracy: 0.6267 - val_loss: 0.9594
# Epoch 3/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 79s 699ms/step - accuracy: 0.6198 - loss: 0.9768 - val_accuracy: 0.6140 - val_loss: 0.9710
# Epoch 4/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 85s 761ms/step - accuracy: 0.6385 - loss: 0.9068 - val_accuracy: 0.6372 - val_loss: 0.9128
# Epoch 5/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 81s 729ms/step - accuracy: 0.6556 - loss: 0.8657 - val_accuracy: 0.6570 - val_loss: 0.8696
# Epoch 6/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 80s 713ms/step - accuracy: 0.7010 - loss: 0.8173 - val_accuracy: 0.6105 - val_loss: 1.0102
# Epoch 7/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 80s 720ms/step - accuracy: 0.7044 - loss: 0.7955 - val_accuracy: 0.6744 - val_loss: 0.8114
# Epoch 8/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 80s 718ms/step - accuracy: 0.7002 - loss: 0.7490 - val_accuracy: 0.6977 - val_loss: 0.8267
# Epoch 9/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 86s 773ms/step - accuracy: 0.7199 - loss: 0.7025 - val_accuracy: 0.6919 - val_loss: 0.8362
# Epoch 10/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 817ms/step - accuracy: 0.7403 - loss: 0.6699 - val_accuracy: 0.6779 - val_loss: 0.8691
# Epoch 11/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 94s 846ms/step - accuracy: 0.7356 - loss: 0.6776 - val_accuracy: 0.6930 - val_loss: 0.7946
# Epoch 12/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 88s 729ms/step - accuracy: 0.7905 - loss: 0.5552 - val_accuracy: 0.6942 - val_loss: 0.8088
# Epoch 13/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 865ms/step - accuracy: 0.7972 - loss: 0.5382 - val_accuracy: 0.7116 - val_loss: 0.8190
# Epoch 14/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 93s 834ms/step - accuracy: 0.8070 - loss: 0.5324 - val_accuracy: 0.6605 - val_loss: 1.0256
# Epoch 15/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.7679 - loss: 0.6019 - val_accuracy: 0.7140 - val_loss: 0.9010
# Epoch 16/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 110s 994ms/step - accuracy: 0.8139 - loss: 0.4905 - val_accuracy: 0.6977 - val_loss: 0.9317
# Epoch 17/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 110s 994ms/step - accuracy: 0.8332 - loss: 0.4407 - val_accuracy: 0.6860 - val_loss: 0.8945
# Epoch 18/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 103s 927ms/step - accuracy: 0.8012 - loss: 0.5343 - val_accuracy: 0.6977 - val_loss: 0.9403
# Epoch 19/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.8583 - loss: 0.3784 - val_accuracy: 0.6953 - val_loss: 0.9440
# Epoch 20/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 94s 840ms/step - accuracy: 0.8678 - loss: 0.3491 - val_accuracy: 0.6965 - val_loss: 1.0030

# %%
plt.plot(history.history['accuracy'], label='Точность на тренировочных данных')
plt.plot(history.history['val_accuracy'], label='Точность на валидационных данных')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Loss на тренировочных данных')
plt.plot(history.history['val_loss'], label='Loss на валидационных данных')
plt.legend()
plt.show()

# %% [markdown]
# Создадим автоэнкодер и обучим его, для того, чтобы использовать в классификаторе на основе полносвязных слоёв.

# %%
input_img = tf.keras.Input(shape=(128, 128, 3))
x = layers.Flatten()(input_img)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
encoded = layers.Dense(64, activation='relu')(x)


x = layers.Dense(128, activation='relu')(encoded)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128 * 128 * 3, activation='sigmoid')(x)
decoded = layers.Reshape((128, 128, 3))(x)

autoencoder = tf.keras.Model(input_img, decoded)
encoder = tf.keras.Model(input_img, encoded)

autoencoder.compile(optimizer='adam', loss='mse')

# %%
all_x = []

for _ in range(len(train_data)):
    x_batch, _ = next(train_data)
    all_x.append(x_batch)

all_x = np.vstack(all_x)

all_x_dev = []

for _ in range(len(val_data)):
    x_batch, _ = next(val_data)
    all_x_dev.append(x_batch)

all_x_dev = np.vstack(all_x_dev)

# %%
autoencoder.compile(optimizer='adam', loss='mse')
history_ae = autoencoder.fit(all_x, all_x, validation_data=(all_x_dev, all_x_dev), epochs=20)
# Out:
# Epoch 1/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 36s 282ms/step - loss: 0.0747 - val_loss: 0.0586
# Epoch 2/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 272ms/step - loss: 0.0557 - val_loss: 0.0648
# Epoch 3/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 28s 256ms/step - loss: 0.0576 - val_loss: 0.0529
# Epoch 4/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 270ms/step - loss: 0.0484 - val_loss: 0.0490
# Epoch 5/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 29s 263ms/step - loss: 0.0460 - val_loss: 0.0479
# Epoch 6/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 279ms/step - loss: 0.0438 - val_loss: 0.0448
# Epoch 7/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 291ms/step - loss: 0.0415 - val_loss: 0.0521
# Epoch 8/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 39s 268ms/step - loss: 0.0447 - val_loss: 0.0435
# Epoch 9/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 29s 262ms/step - loss: 0.0387 - val_loss: 0.0410
# Epoch 10/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 37s 334ms/step - loss: 0.0398 - val_loss: 0.0392
# Epoch 11/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 33s 300ms/step - loss: 0.0365 - val_loss: 0.0381
# Epoch 12/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 294ms/step - loss: 0.0358 - val_loss: 0.0369
# Epoch 13/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 287ms/step - loss: 0.0347 - val_loss: 0.0374
# Epoch 14/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 274ms/step - loss: 0.0346 - val_loss: 0.0353
# Epoch 15/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - loss: 0.0327 - val_loss: 0.0363
# Epoch 16/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 279ms/step - loss: 0.0334 - val_loss: 0.0358
# Epoch 17/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - loss: 0.0331 - val_loss: 0.0352
# Epoch 18/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 279ms/step - loss: 0.0324 - val_loss: 0.0348
# Epoch 19/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 276ms/step - loss: 0.0314 - val_loss: 0.0353
# Epoch 20/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 29s 269ms/step - loss: 0.0316 - val_loss: 0.0343

# %%
plt.plot(history_ae.history['loss'], label='Loss на тренировочных данных')
plt.plot(history_ae.history['val_loss'], label='Loss на валидационных данных')
plt.legend()
plt.show()

# %% [markdown]
# Создадим классификатор на основе полносвязных слоёв, который будет использовать encoder для сжатия изображения

# %%
for layer in encoder.layers:
    layer.trainable = False


classifier_input = encoder.input
x = encoder.output
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.25)(x)
x = layers.Dense(64, activation='relu')(x)
output = layers.Dense(5, activation='softmax')(x)

classifier = tf.keras.Model(classifier_input, output)

# %%
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history_cls = classifier.fit(train_data, validation_data=val_data, epochs=20)
# Out:
# Epoch 1/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 66s 545ms/step - accuracy: 0.2950 - loss: 2.3897 - val_accuracy: 0.3884 - val_loss: 1.3614
# Epoch 2/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 519ms/step - accuracy: 0.3881 - loss: 1.4225 - val_accuracy: 0.4140 - val_loss: 1.2923
# Epoch 3/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 59s 518ms/step - accuracy: 0.3970 - loss: 1.3694 - val_accuracy: 0.4593 - val_loss: 1.2614
# Epoch 4/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 519ms/step - accuracy: 0.4349 - loss: 1.2946 - val_accuracy: 0.4174 - val_loss: 1.2761
# Epoch 5/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 59s 517ms/step - accuracy: 0.4510 - loss: 1.2716 - val_accuracy: 0.4395 - val_loss: 1.2608
# Epoch 6/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 61s 540ms/step - accuracy: 0.4463 - loss: 1.2965 - val_accuracy: 0.4302 - val_loss: 1.2447
# Epoch 7/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 60s 518ms/step - accuracy: 0.4664 - loss: 1.2696 - val_accuracy: 0.4430 - val_loss: 1.2450
# Epoch 8/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 66s 577ms/step - accuracy: 0.4613 - loss: 1.2341 - val_accuracy: 0.4430 - val_loss: 1.2465
# Epoch 9/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 63s 549ms/step - accuracy: 0.4453 - loss: 1.2344 - val_accuracy: 0.4500 - val_loss: 1.2238
# Epoch 10/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 65s 568ms/step - accuracy: 0.4706 - loss: 1.2433 - val_accuracy: 0.4512 - val_loss: 1.2345
# Epoch 11/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 63s 548ms/step - accuracy: 0.4611 - loss: 1.2217 - val_accuracy: 0.4674 - val_loss: 1.2206
# Epoch 12/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 63s 555ms/step - accuracy: 0.4700 - loss: 1.2320 - val_accuracy: 0.4779 - val_loss: 1.2076
# Epoch 13/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 62s 538ms/step - accuracy: 0.4657 - loss: 1.2106 - val_accuracy: 0.4523 - val_loss: 1.2509
# Epoch 14/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 57s 497ms/step - accuracy: 0.4705 - loss: 1.2174 - val_accuracy: 0.4628 - val_loss: 1.2276
# Epoch 15/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 28s 244ms/step - accuracy: 0.4618 - loss: 1.2147 - val_accuracy: 0.4884 - val_loss: 1.2181
# Epoch 16/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 27s 235ms/step - accuracy: 0.4712 - loss: 1.2017 - val_accuracy: 0.4512 - val_loss: 1.2320
# Epoch 17/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 32s 279ms/step - accuracy: 0.4996 - loss: 1.1655 - val_accuracy: 0.4453 - val_loss: 1.2244
# Epoch 18/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 31s 267ms/step - accuracy: 0.4946 - loss: 1.1930 - val_accuracy: 0.4640 - val_loss: 1.2240
# Epoch 19/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 263ms/step - accuracy: 0.5011 - loss: 1.1851 - val_accuracy: 0.4767 - val_loss: 1.2353
# Epoch 20/20
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 30s 258ms/step - accuracy: 0.5046 - loss: 1.1820 - val_accuracy: 0.4535 - val_loss: 1.2135

# %%
plt.plot(history_cls.history['accuracy'], label='Точность на тренировочных данных')
plt.plot(history_cls.history['val_accuracy'], label='Точность на валидационных данных')
plt.legend()
plt.show()

plt.plot(history_cls.history['loss'], label='Loss на тренировочных данных')
plt.plot(history_cls.history['val_loss'], label='Loss на валидационных данных')
plt.legend()
plt.show()

# %% [markdown]
# Сравним полученные модели сверточной нейронной сети и классификатора на основе полносвязных слоёв по метрике accuracy

# %%
_, acc_cnn = model.evaluate(val_data)
_, acc_dense = classifier.evaluate(val_data)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 326ms/step - accuracy: 0.7073 - loss: 0.9588
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 0.4873 - loss: 1.1872

# %%
print(f"Accuracy для сверточной: {acc_cnn:.4f}")
print(f"Accuracy для полносвязной: {acc_dense:.4f}")
# Out:
# Accuracy для сверточной: 0.6895
# Accuracy для полносвязной: 0.4849

# %% [markdown]
# Как можно заметить, лучший результат показала свёрточная модель.
# Её точность по метрике accuracy составляет 0.7081

# %% [markdown]
# Для демонстрация результата обучим модель большим количество эпох и посмотрим на результат на примере нескольких картинок

# %%
history = model.fit(train_data, epochs=100, validation_data=val_data)
# Out:
# Epoch 1/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 822ms/step - accuracy: 0.8720 - loss: 0.3505 - val_accuracy: 0.7256 - val_loss: 0.9882
# Epoch 2/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 90s 814ms/step - accuracy: 0.8993 - loss: 0.2867 - val_accuracy: 0.7000 - val_loss: 1.1406
# Epoch 3/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 92s 815ms/step - accuracy: 0.8964 - loss: 0.2797 - val_accuracy: 0.7244 - val_loss: 1.1090
# Epoch 4/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 819ms/step - accuracy: 0.9014 - loss: 0.2702 - val_accuracy: 0.7209 - val_loss: 0.9181
# Epoch 5/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 90s 814ms/step - accuracy: 0.8817 - loss: 0.3269 - val_accuracy: 0.7093 - val_loss: 1.1042
# Epoch 6/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 87s 793ms/step - accuracy: 0.9187 - loss: 0.2472 - val_accuracy: 0.7047 - val_loss: 1.1995
# Epoch 7/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 87s 780ms/step - accuracy: 0.9205 - loss: 0.2149 - val_accuracy: 0.6942 - val_loss: 1.2047
# Epoch 8/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 823ms/step - accuracy: 0.9161 - loss: 0.2285 - val_accuracy: 0.6977 - val_loss: 1.4317
# Epoch 9/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 89s 803ms/step - accuracy: 0.9442 - loss: 0.1603 - val_accuracy: 0.7186 - val_loss: 1.2641
# Epoch 10/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 107s 967ms/step - accuracy: 0.9441 - loss: 0.1695 - val_accuracy: 0.6860 - val_loss: 1.3200
# Epoch 11/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 855ms/step - accuracy: 0.9302 - loss: 0.1994 - val_accuracy: 0.7047 - val_loss: 1.1725
# Epoch 12/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 92s 833ms/step - accuracy: 0.9472 - loss: 0.1499 - val_accuracy: 0.7140 - val_loss: 1.4045
# Epoch 13/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 868ms/step - accuracy: 0.9418 - loss: 0.1657 - val_accuracy: 0.7244 - val_loss: 1.2163
# Epoch 14/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 799ms/step - accuracy: 0.9546 - loss: 0.1316 - val_accuracy: 0.7233 - val_loss: 1.4240
# Epoch 15/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 109s 985ms/step - accuracy: 0.9572 - loss: 0.1213 - val_accuracy: 0.7209 - val_loss: 1.3815
# Epoch 16/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 866ms/step - accuracy: 0.9522 - loss: 0.1426 - val_accuracy: 0.7070 - val_loss: 1.3410
# Epoch 17/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9621 - loss: 0.1194 - val_accuracy: 0.7244 - val_loss: 1.3956
# Epoch 18/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 90s 814ms/step - accuracy: 0.9680 - loss: 0.1106 - val_accuracy: 0.7081 - val_loss: 1.5498
# Epoch 19/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 98s 881ms/step - accuracy: 0.9589 - loss: 0.1264 - val_accuracy: 0.7209 - val_loss: 1.3857
# Epoch 20/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 104s 942ms/step - accuracy: 0.9610 - loss: 0.1084 - val_accuracy: 0.6977 - val_loss: 1.4284
# Epoch 21/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9511 - loss: 0.1460 - val_accuracy: 0.6814 - val_loss: 1.4352
# Epoch 22/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 102s 925ms/step - accuracy: 0.9629 - loss: 0.1173 - val_accuracy: 0.7116 - val_loss: 1.4577
# Epoch 23/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 105s 951ms/step - accuracy: 0.9633 - loss: 0.0986 - val_accuracy: 0.7035 - val_loss: 1.6467
# Epoch 24/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9649 - loss: 0.1035 - val_accuracy: 0.6884 - val_loss: 1.5913
# Epoch 25/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 122s 1s/step - accuracy: 0.9553 - loss: 0.1323 - val_accuracy: 0.7279 - val_loss: 1.4837
# Epoch 26/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 124s 1s/step - accuracy: 0.9707 - loss: 0.0857 - val_accuracy: 0.7360 - val_loss: 1.5649
# Epoch 27/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.9684 - loss: 0.0808 - val_accuracy: 0.6907 - val_loss: 1.6953
# Epoch 28/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9734 - loss: 0.0845 - val_accuracy: 0.7151 - val_loss: 1.8498
# Epoch 29/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9646 - loss: 0.1069 - val_accuracy: 0.7128 - val_loss: 1.6519
# Epoch 30/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9701 - loss: 0.0983 - val_accuracy: 0.7174 - val_loss: 1.5787
# Epoch 31/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 101s 885ms/step - accuracy: 0.9688 - loss: 0.0862 - val_accuracy: 0.7163 - val_loss: 1.7673
# Epoch 32/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 0.9832 - loss: 0.0596 - val_accuracy: 0.7233 - val_loss: 1.6159
# Epoch 33/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9846 - loss: 0.0501 - val_accuracy: 0.7047 - val_loss: 1.5516
# Epoch 34/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9437 - loss: 0.1859 - val_accuracy: 0.7233 - val_loss: 1.4648
# Epoch 35/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9822 - loss: 0.0588 - val_accuracy: 0.7151 - val_loss: 1.7749
# Epoch 36/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9813 - loss: 0.0643 - val_accuracy: 0.7337 - val_loss: 1.8334
# Epoch 37/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 103s 934ms/step - accuracy: 0.9751 - loss: 0.0771 - val_accuracy: 0.7233 - val_loss: 1.7443
# Epoch 38/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9734 - loss: 0.0771 - val_accuracy: 0.7221 - val_loss: 1.7578
# Epoch 39/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 97s 876ms/step - accuracy: 0.9744 - loss: 0.0784 - val_accuracy: 0.7198 - val_loss: 1.7111
# Epoch 40/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 854ms/step - accuracy: 0.9844 - loss: 0.0474 - val_accuracy: 0.7267 - val_loss: 1.9385
# Epoch 41/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 101s 906ms/step - accuracy: 0.9079 - loss: 0.3372 - val_accuracy: 0.7093 - val_loss: 1.5753
# Epoch 42/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.9531 - loss: 0.1390 - val_accuracy: 0.7000 - val_loss: 1.7029
# Epoch 43/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 82s 735ms/step - accuracy: 0.9632 - loss: 0.0890 - val_accuracy: 0.7163 - val_loss: 1.5115
# Epoch 44/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 80s 717ms/step - accuracy: 0.9734 - loss: 0.0719 - val_accuracy: 0.7163 - val_loss: 1.6034
# Epoch 45/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 92s 833ms/step - accuracy: 0.9785 - loss: 0.0628 - val_accuracy: 0.7279 - val_loss: 1.5555
# Epoch 46/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.9823 - loss: 0.0583 - val_accuracy: 0.7105 - val_loss: 2.0801
# Epoch 47/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 858ms/step - accuracy: 0.9852 - loss: 0.0508 - val_accuracy: 0.7012 - val_loss: 2.0701
# Epoch 48/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 93s 836ms/step - accuracy: 0.9737 - loss: 0.0862 - val_accuracy: 0.7221 - val_loss: 1.9184
# Epoch 49/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 817ms/step - accuracy: 0.9734 - loss: 0.0791 - val_accuracy: 0.7070 - val_loss: 1.8759
# Epoch 50/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 101s 907ms/step - accuracy: 0.9872 - loss: 0.0423 - val_accuracy: 0.7256 - val_loss: 1.8277
# Epoch 51/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 856ms/step - accuracy: 0.9860 - loss: 0.0379 - val_accuracy: 0.7267 - val_loss: 1.9469
# Epoch 52/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 819ms/step - accuracy: 0.9908 - loss: 0.0343 - val_accuracy: 0.6988 - val_loss: 2.0566
# Epoch 53/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 99s 884ms/step - accuracy: 0.9749 - loss: 0.0897 - val_accuracy: 0.6930 - val_loss: 1.8449
# Epoch 54/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 96s 858ms/step - accuracy: 0.9724 - loss: 0.0900 - val_accuracy: 0.7395 - val_loss: 1.7725
# Epoch 55/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 852ms/step - accuracy: 0.9891 - loss: 0.0348 - val_accuracy: 0.7105 - val_loss: 1.8278
# Epoch 56/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 103s 909ms/step - accuracy: 0.9803 - loss: 0.0690 - val_accuracy: 0.7256 - val_loss: 1.9036
# Epoch 57/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 97s 830ms/step - accuracy: 0.9782 - loss: 0.0746 - val_accuracy: 0.7035 - val_loss: 1.7927
# Epoch 58/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 86s 779ms/step - accuracy: 0.9657 - loss: 0.1278 - val_accuracy: 0.7128 - val_loss: 1.7164
# Epoch 59/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 86s 772ms/step - accuracy: 0.9817 - loss: 0.0572 - val_accuracy: 0.7128 - val_loss: 1.8852
# Epoch 60/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 91s 819ms/step - accuracy: 0.9864 - loss: 0.0536 - val_accuracy: 0.7035 - val_loss: 1.8347
# Epoch 61/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 93s 836ms/step - accuracy: 0.9911 - loss: 0.0299 - val_accuracy: 0.7198 - val_loss: 2.1901
# Epoch 62/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 113s 1s/step - accuracy: 0.9909 - loss: 0.0331 - val_accuracy: 0.7058 - val_loss: 2.0703
# Epoch 63/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 95s 854ms/step - accuracy: 0.9894 - loss: 0.0361 - val_accuracy: 0.7314 - val_loss: 1.8786
# Epoch 64/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 99s 819ms/step - accuracy: 0.9888 - loss: 0.0390 - val_accuracy: 0.7093 - val_loss: 2.1192
# Epoch 65/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 108s 972ms/step - accuracy: 0.9855 - loss: 0.0518 - val_accuracy: 0.7140 - val_loss: 2.1159
# Epoch 66/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 114s 1s/step - accuracy: 0.9789 - loss: 0.0665 - val_accuracy: 0.7209 - val_loss: 1.9161
# Epoch 67/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 94s 836ms/step - accuracy: 0.9776 - loss: 0.0718 - val_accuracy: 0.7267 - val_loss: 1.7861
# Epoch 68/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 105s 949ms/step - accuracy: 0.9814 - loss: 0.0501 - val_accuracy: 0.7000 - val_loss: 2.2493
# Epoch 69/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 117s 1s/step - accuracy: 0.9697 - loss: 0.0961 - val_accuracy: 0.7070 - val_loss: 2.0971
# Epoch 70/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 112s 1s/step - accuracy: 0.9821 - loss: 0.0704 - val_accuracy: 0.7291 - val_loss: 1.9420
# Epoch 71/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 860s 8s/step - accuracy: 0.9878 - loss: 0.0453 - val_accuracy: 0.7035 - val_loss: 2.1982
# Epoch 72/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 79s 709ms/step - accuracy: 0.9788 - loss: 0.0745 - val_accuracy: 0.7209 - val_loss: 1.9727
# Epoch 73/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 75s 677ms/step - accuracy: 0.9754 - loss: 0.0845 - val_accuracy: 0.7337 - val_loss: 1.7218
# Epoch 74/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 84s 753ms/step - accuracy: 0.9841 - loss: 0.0577 - val_accuracy: 0.7430 - val_loss: 1.7181
# Epoch 75/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 81s 728ms/step - accuracy: 0.9858 - loss: 0.0395 - val_accuracy: 0.7256 - val_loss: 1.9937
# Epoch 76/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 89s 782ms/step - accuracy: 0.9877 - loss: 0.0372 - val_accuracy: 0.7221 - val_loss: 1.9353
# Epoch 77/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 82s 742ms/step - accuracy: 0.9900 - loss: 0.0389 - val_accuracy: 0.7151 - val_loss: 2.0420
# Epoch 78/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 101s 917ms/step - accuracy: 0.9897 - loss: 0.0347 - val_accuracy: 0.6930 - val_loss: 2.4326
# Epoch 79/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 99s 892ms/step - accuracy: 0.9862 - loss: 0.0368 - val_accuracy: 0.7128 - val_loss: 2.2259
# Epoch 80/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 105s 951ms/step - accuracy: 0.9818 - loss: 0.0616 - val_accuracy: 0.7116 - val_loss: 2.2125
# Epoch 81/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 110s 940ms/step - accuracy: 0.9895 - loss: 0.0369 - val_accuracy: 0.7093 - val_loss: 2.1055
# Epoch 82/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 83s 744ms/step - accuracy: 0.9849 - loss: 0.0505 - val_accuracy: 0.6884 - val_loss: 2.2219
# Epoch 83/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.9851 - loss: 0.0416 - val_accuracy: 0.7000 - val_loss: 2.0568
# Epoch 84/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 93s 842ms/step - accuracy: 0.9863 - loss: 0.0412 - val_accuracy: 0.7093 - val_loss: 2.3174
# Epoch 85/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 118s 1s/step - accuracy: 0.9885 - loss: 0.0413 - val_accuracy: 0.7163 - val_loss: 2.1591
# Epoch 86/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.9836 - loss: 0.0580 - val_accuracy: 0.7244 - val_loss: 2.1240
# Epoch 87/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 104s 906ms/step - accuracy: 0.9813 - loss: 0.0548 - val_accuracy: 0.7116 - val_loss: 1.9696
# Epoch 88/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 119s 1s/step - accuracy: 0.9875 - loss: 0.0434 - val_accuracy: 0.6860 - val_loss: 2.0841
# Epoch 89/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 120s 1s/step - accuracy: 0.9785 - loss: 0.0609 - val_accuracy: 0.7105 - val_loss: 2.0722
# Epoch 90/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 123s 1s/step - accuracy: 0.9824 - loss: 0.0534 - val_accuracy: 0.7047 - val_loss: 2.1439
# Epoch 91/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.9896 - loss: 0.0281 - val_accuracy: 0.7453 - val_loss: 2.1908
# Epoch 92/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 108s 976ms/step - accuracy: 0.9955 - loss: 0.0151 - val_accuracy: 0.7151 - val_loss: 2.1947
# Epoch 93/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 108s 977ms/step - accuracy: 0.9864 - loss: 0.0464 - val_accuracy: 0.7244 - val_loss: 2.1034
# Epoch 94/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 100s 902ms/step - accuracy: 0.9893 - loss: 0.0280 - val_accuracy: 0.7070 - val_loss: 2.0795
# Epoch 95/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 94s 855ms/step - accuracy: 0.9864 - loss: 0.0401 - val_accuracy: 0.7128 - val_loss: 2.0583
# Epoch 96/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.9880 - loss: 0.0447 - val_accuracy: 0.7140 - val_loss: 2.2302
# Epoch 97/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 125s 1s/step - accuracy: 0.9876 - loss: 0.0411 - val_accuracy: 0.7081 - val_loss: 2.2587
# Epoch 98/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.9877 - loss: 0.0476 - val_accuracy: 0.7314 - val_loss: 2.2604
# Epoch 99/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.9851 - loss: 0.0554 - val_accuracy: 0.7105 - val_loss: 2.2892
# Epoch 100/100
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 103s 933ms/step - accuracy: 0.9839 - loss: 0.0462 - val_accuracy: 0.7128 - val_loss: 2.0607

# %%
plt.plot(history.history['accuracy'], label='Точность на тренировочных данных')
plt.plot(history.history['val_accuracy'], label='Точность на валидационных данных')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Loss на тренировочных данных')
plt.plot(history.history['val_loss'], label='Loss на валидационных данных')
plt.legend()
plt.show()

# %% [markdown]
# На графике видно переобучение
